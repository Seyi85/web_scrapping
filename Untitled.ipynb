# %%
# !pip install requests

# %%
# !pip install BeautifulSoup4

# %%
import requests
from bs4 import BeautifulSoup

page =requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.X9EFBdgzY2x")
#print the status of the response.

soup =BeautifulSoup(page.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <!-- Meta -->
#   <meta content="width=device-width" name="viewport"/>
#   <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/>
#   <title>
#    National Weather Service
#   </title>
#   <meta content="National Weather Service" name="DC.title">
#    <meta content="NOAA National Weather Service National Weather Service" name="DC.description"/>
#    <meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/>
#    <meta content="" name="DC.date.created" scheme="ISO8601"/>
#    <meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/>
#    <meta content="weather, National Weather Service" name="DC.keywords"/>
#    <meta content="NOAA's National Weather Service" name="DC.publisher"/>
#    <meta content="National Weather Service" name="DC.contributor"/>
#    <meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/>
#    <meta content="General" name="rating"/>
# ...

# %%
soup.find_all("p")
# Out:
# [<p>
#  <input checked="checked" id="nws" name="affiliate" type="radio" value="nws.noaa.gov"/>
#  <label class="search-scope" for="nws">NWS</label>
#  <input id="noaa" name="affiliate" type="radio" value="noaa.gov"/>
#  <label class="search-scope" for="noaa">All NOAA</label>
#  </p>,
#  <p>Your local forecast office is</p>,
#  <p>
#              A large storm system will track from the Southwest into the Central U.S. and through the East over the next few days. Today, expect some rain and heavy mountain snow for parts of the Four Corners region. On Friday, a few thunderstorms with severe wind gusts are possible over east Texas, rain will spread into the Mid to Lower Mississippi Valley and some snow from the central Plains to Great Lakes.
#              <a href="http://www.wpc.ncep.noaa.gov/discussions/hpcdiscussions.php?disc=pmdspd" target="_blank">Read More &gt;</a>
#  </p>,
#  <p class="myforecast-current">NA</p>,
#  <p class="myforecast-current-lrg">61°F</p>,
# ...

# %%
for p in soup.find_all("p"):
    
    print(p.text)
    
    print("-----")
# Out:
# NWS
#
# All NOAA
#
# -----
# Your local forecast office is
# -----
#
#             A large storm system will track from the Southwest into the Central U.S. and through the East over the next few days. Today, expect some rain and heavy mountain snow for parts of the Four Corners region. On Friday, a few thunderstorms with severe wind gusts are possible over east Texas, rain will spread into the Mid to Lower Mississippi Valley and some snow from the central Plains to Great Lakes.
#             Read More >
#
# -----
# NA
# -----
# 61°F
# -----
# 16°C
# -----
# More Information:
# -----
# Local Forecast OfficeMore Local Wx3 Day HistoryMobile WeatherHourly Weather Forecast
# -----
# ThisAfternoon
# -----
#
# -----
# Sunny
# -----
# High: 61 °F
# -----
# Tonight
# -----
#
# -----
# Partly Cloudy
# -----
# Low: 47 °F
# -----
# Friday
# -----
#
# -----
# Mostly Sunny
# -----
# High: 58 °F
# -----
# FridayNight
# -----
#
# -----
# Chance Rain
# -----
# Low: 51 °F
# -----
# Saturday
# -----
#
# ...

# %%
#To find the number of class we need an identifier(id)

soup.find(id="seven-day-forecast-container")




#To get the days, descriptions,temperature,we need to find the class

seven = soup.find(id="seven-day-forecast-container")
seven
# Out:
# <div id="seven-day-forecast-container"><ul class="list-unstyled" id="seven-day-forecast-list"><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">This<br/>Afternoon</p>
# <p><img alt="This Afternoon: Sunny, with a high near 61. West wind around 17 mph, with gusts as high as 22 mph. " class="forecast-icon" src="newimages/medium/few.png" title="This Afternoon: Sunny, with a high near 61. West wind around 17 mph, with gusts as high as 22 mph. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 61 °F</p></div></li><li class="forecast-tombstone">
# <div class="tombstone-container">
# <p class="period-name">Tonight<br/><br/></p>
# ...

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-ab0680a89434> in <module>
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
name = seven.find_all(class_="period-name")
name
# Out:
# [<p class="period-name">This<br/>Afternoon</p>,
#  <p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Friday<br/><br/></p>,
#  <p class="period-name">Friday<br/>Night</p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>,
#  <p class="period-name">Monday<br/><br/></p>]

# %%
name = [day.text for day in name]
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-234b31abbce9> in <module>
# ----> 1 name = [day.text for day in name]
#       2 name
#       3
#
# NameError: name 'name' is not defined

# %% [markdown]
# Des = figure.find_all(class_="short-desc")
# des

# %%
Dola= seven.find_all(class_="short-desc") 

Dola
# Out:
# [<p class="short-desc">Sunny</p>,
#  <p class="short-desc">Partly Cloudy</p>,
#  <p class="short-desc">Mostly Sunny</p>,
#  <p class="short-desc">Chance Rain</p>,
#  <p class="short-desc">Chance Rain</p>,
#  <p class="short-desc">Chance Rain</p>,
#  <p class="short-desc">Rain Likely</p>,
#  <p class="short-desc">Chance Rain<br/>then Mostly<br/>Cloudy</p>,
#  <p class="short-desc">Partly Sunny</p>]

# %%
Dola = [desc.text for desc in Dola]
Dola
# Out:
# ['Sunny',
#  'Partly Cloudy',
#  'Mostly Sunny',
#  'Chance Rain',
#  'Chance Rain',
#  'Chance Rain',
#  'Rain Likely',
#  'Chance Rainthen MostlyCloudy',
#  'Partly Sunny']

# %%
temperature = seven.find_all(class_="temp")
temperature
# Out:
# [<p class="temp temp-high">High: 61 °F</p>,
#  <p class="temp temp-low">Low: 47 °F</p>,
#  <p class="temp temp-high">High: 58 °F</p>,
#  <p class="temp temp-low">Low: 51 °F</p>,
#  <p class="temp temp-high">High: 60 °F</p>,
#  <p class="temp temp-low">Low: 52 °F</p>,
#  <p class="temp temp-high">High: 61 °F</p>,
#  <p class="temp temp-low">Low: 49 °F</p>,
#  <p class="temp temp-high">High: 60 °F</p>]

# %%
temperature = [temp.text for temp in temperature]
temperature
# Out:
# ['High: 61 °F',
#  'Low: 47 °F',
#  'High: 58 °F',
#  'Low: 51 °F',
#  'High: 60 °F',
#  'Low: 52 °F',
#  'High: 61 °F',
#  'Low: 49 °F',
#  'High: 60 °F']

# %%
import pandas as pd

# %%
df = pd.DataFrame({
     "day": name,
     "Description": Dola,
     "temperature": temps
})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-45904ab5dccc> in <module>
#       1 df = pd.DataFrame({
# ----> 2      "day": name,
#       3      "Description": Dola,
#       4      "temperature": temps
#       5 })
#
# NameError: name 'name' is not defined
